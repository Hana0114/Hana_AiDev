# %%
from sklearn.ensemble import RandomForestClassifier as RandomForest
from sklearn.model_selection import train_test_split 

feature = ['temperature', 'precipitation', 'water_level', 'humidity', 'cultivated area'] 
X = data[feature]
y = data[risk]
