# %%
import requests as req

product = input("product")
page = int(input("page"))

for page in range(1, page + 1):
    url = f"https://api.digikala.com/v1/search/?q{product}&page{page}"
    response = req.get(url)
print(response)

#if response == 200
# Out:
# <Response [200]>
